# %%
import pandas as pd
import numpy as np
import streamlit as st
from streamlit_lottie import st_lottie
import json
from PIL import Image
import plotly.express as px
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot, plot
import plotly as py
init_notebook_mode(connected=True)
from wordcloud import WordCloud
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
total= pd.read_csv("Twitch_game_data.csv", sep=",", encoding="'cp1252'")
total=total.drop(["Peak_channels","Streamers","Avg_channels"], axis=1)
total
# Out:
#        Rank                              Game  Month  Year   Hours_watched  \
# 0         1                 League of Legends      1  2016        94377226
# 1         2  Counter-Strike: Global Offensive      1  2016        47832863
# 2         3                            Dota 2      1  2016        45185893
# 3         4                       Hearthstone      1  2016        39936159
# 4         5       Call of Duty: Black Ops III      1  2016        16153057
# ...     ...                               ...    ...   ...             ...
# 16995   196       Tom Clancy's The Division 2      1  2023  666943(118.3%)
# 16996   197                   Persona 5 Royal      1  2023   664503(-2.9%)
# 16997   198                        Bloodborne      1  2023   663078(59.1%)
# 16998   199               PowerWash Simulator      1  2023  657644(356.0%)
# 16999   200                    Eternal Return      1  2023    642217(2.4%)
#
#       Hours_Streamed   Peak_viewers  Avg_viewers Avg_viewer_ratio
# ...

# %%
#IMPORTAR EL DATASET Y RENOMBRAR COLUMNAS
total1=total.set_index(["Year"])
total1.rename({"Avg_viewer_ratio":"Avg_H.Watched/H.Streamed"}, axis=1, inplace=True)
total1=total1[["Month","Rank","Game","Hours_watched","Hours_Streamed","Peak_viewers","Avg_viewers","Avg_H.Watched/H.Streamed"]]
total1
# Out:
#       Month  Rank                              Game   Hours_watched  \
# Year
# 2016      1     1                 League of Legends        94377226
# 2016      1     2  Counter-Strike: Global Offensive        47832863
# 2016      1     3                            Dota 2        45185893
# 2016      1     4                       Hearthstone        39936159
# 2016      1     5       Call of Duty: Black Ops III        16153057
# ...     ...   ...                               ...             ...
# 2023      1   196       Tom Clancy's The Division 2  666943(118.3%)
# 2023      1   197                   Persona 5 Royal   664503(-2.9%)
# 2023      1   198                        Bloodborne   663078(59.1%)
# 2023      1   199               PowerWash Simulator  657644(356.0%)
# 2023      1   200                    Eternal Return    642217(2.4%)
#
#      Hours_Streamed   Peak_viewers  Avg_viewers Avg_H.Watched/H.Streamed
# Year
# ...

# %%
total1["Hours_watched"] = total1["Hours_watched"].str.split("(", expand=True)[0]
total1["Hours_Streamed"] = total1["Hours_Streamed"].str.split("(", expand=True)[0]
total1["Hours_Streamed"] = total1["Hours_Streamed"].str.split("h", expand=True)[0]
total1["Peak_viewers"] = total1["Peak_viewers"].str.split("(", expand=True)[0]
total1["Avg_viewers"] = total1["Avg_viewers"].str.split("(", expand=True)[0]
total1["Avg_H.Watched/H.Streamed"] = total1["Avg_H.Watched/H.Streamed"].str.split("(", expand=True)[0]
total1
# Out:
#       Month  Rank                              Game Hours_watched  \
# Year
# 2016      1     1                 League of Legends      94377226
# 2016      1     2  Counter-Strike: Global Offensive      47832863
# 2016      1     3                            Dota 2      45185893
# 2016      1     4                       Hearthstone      39936159
# 2016      1     5       Call of Duty: Black Ops III      16153057
# ...     ...   ...                               ...           ...
# 2023      1   196       Tom Clancy's The Division 2        666943
# 2023      1   197                   Persona 5 Royal        664503
# 2023      1   198                        Bloodborne        663078
# 2023      1   199               PowerWash Simulator        657644
# 2023      1   200                    Eternal Return        642217
#
#      Hours_Streamed Peak_viewers Avg_viewers Avg_H.Watched/H.Streamed
# Year
# 2016       1362044        530270      127021                    69.29
# ...

# %%
#SACAR LOS DATOS POR AÑO
total2016=total1.loc["2016"]
total2017=total1.loc["2017"]
total2018=total1.loc["2018"]
total2019=total1.loc["2019"]
total2020=total1.loc["2020"]
total2021=total1.loc["2021"]
total2022=total1.loc["2022"]

# %%
#En los valores de "Hours_Watched" del años 2022 hay (%), por lo que hay que quitarlo del valor.
total2022["Hours_watched"] = total2022["Hours_watched"].str.split("(", expand=True)[0]

# %%
#JUEGOS MAS VISTOS 2016. CREO DF POR LOS 10 MAS VISTOS (juegos_2016) Y OTRO DF POR TIPO DE JUEGO(tipos_juegos2016)
copiatotal2016= total2016.copy()
copiatotal2016['Hours_watched'] = copiatotal2016['Hours_watched'].astype(float)
principales2016= copiatotal2016.groupby("Game").sum()
principales_juegos_2016=principales2016.drop(["Month","Rank"], axis=1)
principales_juegos_2016.sort_values(by="Hours_watched", ascending=False, inplace=True)
principales_juegos_2016.drop(["Talk Shows & Podcasts"], axis=0, inplace=True)
juegos_2016= principales_juegos_2016.head(10)
los_10_principales_juegos_2016= principales_juegos_2016.head(10)
los_10_principales_juegos_2016['Tipo de juego'] = ["MOBA", "Shooter", "MOBA", "Juego de cartas", "Shooter","MMO","Shooter", "Sandbox", "Shooter", "Shooter"]
tipos_juegos_2016= los_10_principales_juegos_2016.drop(["Hours_watched"], axis=1)

# %%
#JUEGOS MAS VISTOS 2017. CREO DF POR LOS 10 MAS VISTOS (juegos_2017) Y OTRO DF POR TIPO DE JUEGO(tipos_juegos2017)
copiatotal2017= total2017.copy()
copiatotal2017['Hours_watched'] = copiatotal2017['Hours_watched'].astype(float)
principales2017= copiatotal2017.groupby("Game").sum()
principales_juegos_2017=principales2017.drop(["Month","Rank"], axis=1)
principales_juegos_2017.sort_values(by="Hours_watched", ascending=False, inplace=True)
principales_juegos_2017.drop(["IRL"], axis=0, inplace=True)
juegos_2017= principales_juegos_2017.head(10)
los_10_principales_juegos_2017= principales_juegos_2017.head(10)
los_10_principales_juegos_2017['Tipo de juego'] = ["MOBA", "Shooter", "MOBA", "Juego de cartas", "Shooter","Shooter","MMO","Sandbox","Shooter", "Shooter"]
tipos_juegos_2017= los_10_principales_juegos_2017.drop(["Hours_watched"], axis=1)

# %%
#JUEGOS MAS VISTOS 2018.CREO DF POR LOS 10 MAS VISTOS (juegos_2087) Y OTRO DF POR TIPO DE JUEGO(tipos_juegos2018)
copiatotal2018= total2018.copy()
copiatotal2018['Hours_watched'] = copiatotal2018['Hours_watched'].astype(float)
principales2018= copiatotal2018.groupby("Game").sum()
principales_juegos_2018=principales2018.drop(["Month","Rank"], axis=1)
principales_juegos_2018.sort_values(by="Hours_watched", ascending=False, inplace=True)
principales_juegos_2018.drop(["IRL","Just Chatting"], axis=0, inplace=True)
juegos_2018= principales_juegos_2018.head(10)
los_10_principales_juegos_2018= principales_juegos_2018.head(10)
los_10_principales_juegos_2018['Tipo de juego'] = ["Shooter","MOBA","MOBA","Shooter", "Shooter", "Juego de cartas", "Shooter","MMO","Sandbox","Shooter"]
tipos_juegos_2018= los_10_principales_juegos_2018.drop(["Hours_watched"], axis=1)

# %%
#JUEGOS MAS VISTOS 2019.CREO DF POR LOS 10 MAS VISTOS (juegos_2019) Y OTRO DF POR TIPO DE JUEGO(tipos_juegos2019)
copiatotal2019= total2019.copy()
copiatotal2019['Hours_watched'] = copiatotal2019['Hours_watched'].astype(float)
principales2019= copiatotal2019.groupby("Game").sum()
principales_juegos_2019=principales2019.drop(["Month","Rank"], axis=1)
principales_juegos_2019.sort_values(by="Hours_watched", ascending=False, inplace=True)
principales_juegos_2019.drop(["Just Chatting"], axis=0, inplace=True)
juegos_2019= principales_juegos_2019.head(10)
los_10_principales_juegos_2019= principales_juegos_2019.head(10)
los_10_principales_juegos_2019['Tipo de juego'] = ["MOBA","Shooter","Sandbox","MOBA","Shooter", "MMO","Shooter","Shooter", "Juego de cartas","Shooter"]
tipos_juegos_2019= los_10_principales_juegos_2019.drop(["Hours_watched"], axis=1)

# %%
#JUEGOS MAS VISTOS 2020.CREO DF POR LOS 10 MAS VISTOS (juegos_2020) Y OTRO DF POR TIPO DE JUEGO(tipos_juegos2020)
copiatotal2020= total2020.copy()
copiatotal2020['Hours_watched'] = copiatotal2020['Hours_watched'].astype(float)
principales2020= copiatotal2020.groupby("Game").sum()
principales_juegos_2020=principales2020.drop(["Month","Rank"], axis=1)
principales_juegos_2020.sort_values(by="Hours_watched", ascending=False, inplace=True)
principales_juegos_2020.drop(["Just Chatting"], axis=0, inplace=True)
juegos_2020= principales_juegos_2020.head(10)
los_10_principales_juegos_2020= principales_juegos_2020.head(10)
los_10_principales_juegos_2020['Tipo de juego'] = ["MOBA","Shooter","Sandbox","Shooter","Shooter","Shooter","Sandbox","MOBA", "MMO","Multijugador"]
tipos_juegos_2020= los_10_principales_juegos_2020.drop(["Hours_watched"], axis=1)

# %%
#JUEGOS MAS VISTOS 2021.CREO DF POR LOS 10 MAS VISTOS (juegos_2021) Y OTRO DF POR TIPO DE JUEGO(tipos_juegos2021)
copiatotal2021= total2021.copy()
copiatotal2021['Hours_watched'] = copiatotal2021['Hours_watched'].astype(float)
principales2021= copiatotal2021.groupby("Game").sum()
principales_juegos_2021=principales2021.drop(["Month","Rank"], axis=1)
principales_juegos_2021.sort_values(by="Hours_watched", ascending=False, inplace=True)
principales_juegos_2021.drop(["Just Chatting"], axis=0, inplace=True)
juegos_2021= principales_juegos_2021.head(10)
los_10_principales_juegos_2021= principales_juegos_2021.head(10)
los_10_principales_juegos_2021['Tipo de juego'] = ["Sandbox","MOBA","Shooter","Shooter","Sandbox","Shooter","Shooter","Shooter","MOBA", "Supervivencia"]
tipos_juegos_2021= los_10_principales_juegos_2021.drop(["Hours_watched"], axis=1)

# %%
#JUEGOS MAS VISTOS 2022
copiatotal2022= total2022.copy()
copiatotal2022['Hours_watched'] = copiatotal2022['Hours_watched'].astype(float)
principales2022= copiatotal2022.groupby("Game").sum()
principales_juegos_2022=principales2022.drop(["Month","Rank"], axis=1)
principales_juegos_2022.sort_values(by="Hours_watched", ascending=False, inplace=True)
principales_juegos_2022.drop(["Just Chatting"], axis=0, inplace=True)
juegos_2022= principales_juegos_2022.head(10)
los_10_principales_juegos_2022= principales_juegos_2022.head(10)
los_10_principales_juegos_2022['Tipo de juego'] = ["MOBA","Sandbox","Shooter","Shooter","Shooter","Shooter","Sandbox","MOBA","Shooter","MMO"]
tipos_juegos_2022= los_10_principales_juegos_2022.drop(["Hours_watched"], axis=1)

# %%
#GRAFICA-10 JUEGOS MAS JUGADOS POR AÑO
juegos_2016=juegos_2016.reset_index()
juegos_2017=juegos_2017.reset_index()
juegos_2018=juegos_2018.reset_index()
juegos_2019=juegos_2019.reset_index()
juegos_2020=juegos_2020.reset_index()
juegos_2021=juegos_2021.reset_index()
juegos_2022=juegos_2022.reset_index()

# %%
juegos_2016.to_csv("CSV/juegos mas jugados al año/juegos2016.csv", sep=",", index = True)
juegos_2017.to_csv("CSV/juegos mas jugados al año/juegos2017.csv", sep=",", index = True)
juegos_2018.to_csv("CSV/juegos mas jugados al año/juegos2018.csv", sep=",", index = True)
juegos_2019.to_csv("CSV/juegos mas jugados al año/juegos2019.csv", sep=",", index = True)
juegos_2020.to_csv("CSV/juegos mas jugados al año/juegos2020.csv", sep=",", index = True)
juegos_2021.to_csv("CSV/juegos mas jugados al año/juegos2021.csv", sep=",", index = True)
juegos_2022.to_csv("CSV/juegos mas jugados al año/juegos2022.csv", sep=",", index = True)

# %%
#GRAFICA 10 JUEGOS MAS VISTOS EN 7 AÑOS(TOTAL)
copia_total1= total1.copy()
lista = []
for i in copia_total1['Hours_watched']:
    lista.append(float(i))
copia_total1['Hours_watched'] = lista

copia_total1['Hours_watched'] = copia_total1['Hours_watched'].astype(float)
total_juegos= copia_total1.sort_values(by="Game")
y= total_juegos.groupby(["Game"])["Hours_watched"].sum()
y.drop(["Just Chatting"], axis=0,inplace=True)
y.sort_values(ascending=False).head(10)

# %%
#JUEGOS MAS JUGADOS EN 7 AÑOS, GRAFICA LINEAL EN EL TIEMPO POR JUEGO
#LEAGUE OF LEGEND
u= total_juegos[["Game","Hours_watched"]]
u= u.reset_index()
u= u.sort_values(by=["Game","Year"])
u=u[["Game","Year","Hours_watched"]]
u.set_index('Game', inplace=True)
League_of_legends= u.loc["League of Legends"]
League_of_legends.sort_values(by="Year")
League_of_legends= League_of_legends.groupby("Year").sum()

# %%
#FORNITE
u= total_juegos[["Game","Hours_watched"]]
u= u.reset_index()
u= u.sort_values(by=["Game","Year"])
u=u[["Game","Year","Hours_watched"]]
u.set_index('Game', inplace=True)
Fortnite= u.loc["Fortnite"]
Fortnite.sort_values(by="Year")
Fortnite= Fortnite.groupby("Year").sum()
Fortnite

# %%
#Grand Theft Auto V 
u= total_juegos[["Game","Hours_watched"]]
u= u.reset_index()
u= u.sort_values(by=["Game","Year"])
u=u[["Game","Year","Hours_watched"]]
u.set_index('Game', inplace=True)
Grand_Theft_Auto_V = u.loc["Grand Theft Auto V"]
Grand_Theft_Auto_V.sort_values(by="Year")
Grand_Theft_Auto_V= Grand_Theft_Auto_V.groupby("Year").sum()
Grand_Theft_Auto_V

# %%
#Counter-Strike: Global Offensive 
u= total_juegos[["Game","Hours_watched"]]
u= u.reset_index()
u= u.sort_values(by=["Game","Year"])
u=u[["Game","Year","Hours_watched"]]
u.set_index('Game', inplace=True)
Counter_Strike_Global_Offensive = u.loc["Counter-Strike: Global Offensive"]
Counter_Strike_Global_Offensive.sort_values(by="Year")
Counter_Strike_Global_Offensive= Counter_Strike_Global_Offensive.groupby("Year").sum()
Counter_Strike_Global_Offensive

# %%
#DOTA 2
u= total_juegos[["Game","Hours_watched"]]
u= u.reset_index()
u= u.sort_values(by=["Game","Year"])
u=u[["Game","Year","Hours_watched"]]
u.set_index('Game', inplace=True)
Dota_2= u.loc["Dota 2"]
Dota_2.sort_values(by="Year")
Dota_2= Dota_2.groupby("Year").sum()
Dota_2

# %%
#VALORANT
u= total_juegos[["Game","Hours_watched"]]
u= u.reset_index()
u= u.sort_values(by=["Game","Year"])
u=u[["Game","Year","Hours_watched"]]
u.set_index('Game', inplace=True)
Valorant= u.loc["VALORANT"]
Valorant.sort_values(by="Year")
Valorant= Valorant.groupby("Year").sum()
Valorant

# %%
#MINECRAFT
u= total_juegos[["Game","Hours_watched"]]
u= u.reset_index()
u= u.sort_values(by=["Game","Year"])
u=u[["Game","Year","Hours_watched"]]
u.set_index('Game', inplace=True)
Minecraft= u.loc["Minecraft"]
Minecraft.sort_values(by="Year")
Minecraft= Minecraft.groupby("Year").sum()
Minecraft

# %%
#HEARTHSTONE
u= total_juegos[["Game","Hours_watched"]]
u= u.reset_index()
u= u.sort_values(by=["Game","Year"])
u=u[["Game","Year","Hours_watched"]]
u.set_index('Game', inplace=True)
Hearthstone= u.loc["Hearthstone"]
Hearthstone.sort_values(by="Year")
Hearthstone= Hearthstone.groupby("Year").sum()
Hearthstone

# %%
#WORLD OF WARCRAFT
u= total_juegos[["Game","Hours_watched"]]
u= u.reset_index()
u= u.sort_values(by=["Game","Year"])
u=u[["Game","Year","Hours_watched"]]
u.set_index('Game', inplace=True)
World_of_Warcraft= u.loc["World of Warcraft"]
World_of_Warcraft.sort_values(by="Year")
World_of_Warcraft= World_of_Warcraft.groupby("Year").sum()
World_of_Warcraft

# %%
#CALL OF DUTY
u= total_juegos[["Game","Hours_watched"]]
u= u.reset_index()
u= u.sort_values(by=["Game","Year"])
u=u[["Game","Year","Hours_watched"]]
u.set_index('Game', inplace=True)
Call_of_Duty_Warzone= u.loc["Call of Duty: Warzone"]
Call_of_Duty_Warzone.sort_values(by="Year")
Call_of_Duty_Warzone= Call_of_Duty_Warzone.groupby("Year").sum()
Call_of_Duty_Warzone

# %%
#GRAFICA 10 JUEGOS MAS JUGADOS EN 7 AÑOS- LINEAL EN EL TIEMPO
League_of_legends=League_of_legends.reset_index()
Fortnite= Fortnite.reset_index()
Grand_Theft_Auto_V=Grand_Theft_Auto_V.reset_index()
Counter_Strike_Global_Offensive=Counter_Strike_Global_Offensive.reset_index()
Dota_2=Dota_2.reset_index()
Valorant= Valorant.reset_index()
Minecraft= Minecraft.reset_index()
Hearthstone=Hearthstone.reset_index()
World_of_Warcraft=World_of_Warcraft.reset_index()
Call_of_Duty_Warzone=Call_of_Duty_Warzone.reset_index()

# %%
League_of_legends.to_csv("CSV/juegos mas jugados en 7 años/League of legends.csv", sep=",", index = True)
Fortnite.to_csv("CSV/juegos mas jugados en 7 años/Fortnite.csv", sep=",", index = True)
Grand_Theft_Auto_V.to_csv("CSV/juegos mas jugados en 7 años/Grand Theft Auto V.csv", sep=",", index = True)
Counter_Strike_Global_Offensive.to_csv("CSV/juegos mas jugados en 7 años/Counter Strike Global Offensive.csv", sep=",", index = True)
Dota_2.to_csv("CSV/juegos mas jugados en 7 años/Dota 2.csv", sep=",", index = True)
Valorant.to_csv("CSV/juegos mas jugados en 7 años/Valorant.csv", sep=",", index = True)
Minecraft.to_csv("CSV/juegos mas jugados en 7 años/Minecraft.csv", sep=",", index = True)
Hearthstone.to_csv("CSV/juegos mas jugados en 7 años/Hearstone.csv", sep=",", index = True)
World_of_Warcraft.to_csv("CSV/juegos mas jugados en 7 años/World of Warcraft.csv", sep=",", index = True)
Call_of_Duty_Warzone.to_csv("CSV/juegos mas jugados en 7 años/Call of Duty Warzone.csv", sep=",", index = True)

# %%
#GRAFICAS TIPOS DE JUEGOS MAS JUGADOS POR AÑO
tipos_juegos_2016
tipos_juegos_2016_final=tipos_juegos_2016.value_counts()
tipos_juegos_2017
tipos_juegos_2017_final=tipos_juegos_2017.value_counts()
tipos_juegos_2018
tipos_juegos_2018_final=tipos_juegos_2018.value_counts()
tipos_juegos_2019
tipos_juegos_2019_final=tipos_juegos_2019.value_counts()
tipos_juegos_2020
tipos_juegos_2020_final=tipos_juegos_2020.value_counts()
tipos_juegos_2021
tipos_juegos_2021_final=tipos_juegos_2021.value_counts()
tipos_juegos_2022
tipos_juegos_2022_final=tipos_juegos_2022.value_counts()

tipos_juegos_2016_final
tipos_juegos_2017_final
tipos_juegos_2018_final
tipos_juegos_2019_final
tipos_juegos_2020_final
tipos_juegos_2021_final
tipos_juegos_2022_final

# %%
tipos_juegos_2016_final.to_csv("CSV/tipo de juego al año/tipo juegos 2016.csv", sep=",", index = True)
tipos_juegos_2017_final.to_csv("CSV/tipo de juego al año/tipo juegos 2017.csv", sep=",", index = True)
tipos_juegos_2018_final.to_csv("CSV/tipo de juego al año/tipo juegos 2018.csv", sep=",", index = True)
tipos_juegos_2019_final.to_csv("CSV/tipo de juego al año/tipo juegos 2019.csv", sep=",", index = True)
tipos_juegos_2020_final.to_csv("CSV/tipo de juego al año/tipo juegos 2020.csv", sep=",", index = True)
tipos_juegos_2021_final.to_csv("CSV/tipo de juego al año/tipo juegos 2021.csv", sep=",", index = True)
tipos_juegos_2022_final.to_csv("CSV/tipo de juego al año/tipo juegos 2022.csv", sep=",", index = True)

# %%
#GRAFICA TIPO JUEGOS MAS JUGADOS EN 7 AÑOS
total_tipos_juegos= pd.concat([tipos_juegos_2016,tipos_juegos_2017,tipos_juegos_2018,tipos_juegos_2019,tipos_juegos_2020,tipos_juegos_2021,tipos_juegos_2022], axis=0)
total_tipos_juegos_final= total_tipos_juegos.value_counts()

total_tipos_juegos_final

# %%
total_tipos_juegos_final1=total_tipos_juegos_final.to_frame(name='Recuento')
tipos_juegos_final= total_tipos_juegos_final1.reset_index()
tipos_juegos_final

# %%
tipos_juegos_final.to_csv("CSV/tipo de juego en 7 años/tipo juegos en 7 años.csv", sep=",", index = True)

# %%
#HORAS WATCHED POR AÑO
copiatotal2016= total2016.copy()
copiatotal2016['Hours_watched'] = copiatotal2016['Hours_watched'].astype(float)
total_horas_2016= copiatotal2016['Hours_watched'].sum()

copiatotal2017= total2017.copy()
copiatotal2017['Hours_watched'] = copiatotal2017['Hours_watched'].astype(float)
total_horas_2017= copiatotal2017['Hours_watched'].sum()

copiatotal2018= total2018.copy()
copiatotal2018['Hours_watched'] = copiatotal2018['Hours_watched'].astype(float)
total_horas_2018= copiatotal2018['Hours_watched'].sum()

copiatotal2019= total2019.copy()
copiatotal2019['Hours_watched'] = copiatotal2019['Hours_watched'].astype(float)
total_horas_2019= copiatotal2019['Hours_watched'].sum()

copiatotal2020= total2020.copy()
copiatotal2020['Hours_watched'] = copiatotal2020['Hours_watched'].astype(float)
total_horas_2020= copiatotal2020['Hours_watched'].sum()

copiatotal2021= total2021.copy()
copiatotal2021['Hours_watched'] = copiatotal2021['Hours_watched'].astype(float)
total_horas_2021= copiatotal2021['Hours_watched'].sum()

copiatotal2022= total2022.copy()
copiatotal2022['Hours_watched'] = copiatotal2022['Hours_watched'].astype(float)
total_horas_2022= copiatotal2022['Hours_watched'].sum()

# %%
#GRAFICA TOTAL HOURS_WATCHED EN 7 AÑOS
total_horas_2016
total_horas_2017
total_horas_2018
total_horas_2019
total_horas_2020
total_horas_2021
total_horas_2022
total_horas_2022
# Out:
# 20397399743.0

# %%
datos = {'Year':[2016,2017,2018,2019,2020,2021,2022],
'Hours_watched':[total_horas_2016,total_horas_2017,total_horas_2018,total_horas_2019,total_horas_2020,total_horas_2021,total_horas_2022]
 }
total_viewers_7años= pd.DataFrame(datos)
total_viewers_7años=total_viewers_7años.set_index("Year")
total_viewers_7años=total_viewers_7años.reset_index()
total_viewers_7años

# %%
total_viewers_7años.to_csv("CSV/total viewer 7 años/total viewers 7 años.csv", sep=",", index = True)

# %%
#VIEWERS POR MES
total1["Month"] = total1["Month"].astype(int)
total1["Hours_watched"] = total1["Hours_watched"].astype(int)
total1_1= total1.copy()
total1_1=total1_1.groupby("Month")["Hours_watched"].sum()
viewer_mes=pd.DataFrame(total1_1)
viewer_mes=viewer_mes.reset_index()

# %%
viewer_mes.to_csv("CSV/viewer por mes/visualizaciones por mes.csv", sep=",", index = True)

# %%
#PICO DE VIEWERS EN 7 AÑOS
total2022["Peak_viewers"] = total2022["Peak_viewers"].str.split("(", expand=True)[0]
copiatotal_viewers2016= total2016.copy()
copiatotal_viewers2016['Peak_viewers'] = copiatotal_viewers2016['Peak_viewers'].astype(int)
pico_viewers_2016= copiatotal_viewers2016.groupby("Game").sum()
pico_viewers_2016=pico_viewers_2016.drop(["Month","Rank"], axis=1)
pico_viewers_2016.sort_values(by=["Peak_viewers"], ascending=False, inplace=True)
pico_viewers_2016.drop(["Talk Shows & Podcasts"], axis=0, inplace=True)
pico_viewers_2016= pico_viewers_2016.head(1)
pico_viewers_2016["Year"]=[2016]
pico_viewers_2016= pico_viewers_2016.reset_index()
pico_viewers_2016.set_index("Year", inplace=True)

copiatotal_viewers2017= total2017.copy()
copiatotal_viewers2017['Peak_viewers'] = copiatotal_viewers2017['Peak_viewers'].astype(int)
pico_viewers_2017= copiatotal_viewers2017.groupby("Game").sum()
pico_viewers_2017=pico_viewers_2017.drop(["Month","Rank"], axis=1)
pico_viewers_2017.sort_values(by=["Peak_viewers"], ascending=False, inplace=True)
pico_viewers_2017.drop(["Talk Shows & Podcasts"], axis=0, inplace=True)
pico_viewers_2017= pico_viewers_2017.head(1)
pico_viewers_2017["Year"]=[2017]
pico_viewers_2017= pico_viewers_2017.reset_index()
pico_viewers_2017.set_index("Year", inplace=True)

copiatotal_viewers2018= total2018.copy()
copiatotal_viewers2018['Peak_viewers'] = copiatotal_viewers2018['Peak_viewers'].astype(int)
pico_viewers_2018= copiatotal_viewers2018.groupby("Game").sum()
pico_viewers_2018=pico_viewers_2018.drop(["Month","Rank"], axis=1)
pico_viewers_2018.sort_values(by=["Peak_viewers"], ascending=False, inplace=True)
pico_viewers_2018.drop(["Talk Shows & Podcasts"], axis=0, inplace=True)
pico_viewers_2018= pico_viewers_2018.head(1)
pico_viewers_2018["Year"]=[2018]
pico_viewers_2018= pico_viewers_2018.reset_index()
pico_viewers_2018.set_index("Year", inplace=True)

copiatotal_viewers2019= total2019.copy()
copiatotal_viewers2019['Peak_viewers'] = copiatotal_viewers2019['Peak_viewers'].astype(int)
pico_viewers_2019= copiatotal_viewers2019.groupby("Game").sum()
pico_viewers_2019=pico_viewers_2019.drop(["Month","Rank"], axis=1)
pico_viewers_2019.sort_values(by=["Peak_viewers"], ascending=False, inplace=True)
pico_viewers_2019.drop(["Talk Shows & Podcasts"], axis=0, inplace=True)
pico_viewers_2019= pico_viewers_2019.head(1)
pico_viewers_2019["Year"]=[2019]
pico_viewers_2019= pico_viewers_2019.reset_index()
pico_viewers_2019.set_index("Year", inplace=True)

copiatotal_viewers2020= total2020.copy()
copiatotal_viewers2020['Peak_viewers'] = copiatotal_viewers2020['Peak_viewers'].astype(int)
pico_viewers_2020= copiatotal_viewers2020.groupby("Game").sum()
pico_viewers_2020=pico_viewers_2020.drop(["Month","Rank"], axis=1)
pico_viewers_2020.sort_values(by=["Peak_viewers"], ascending=False, inplace=True)
pico_viewers_2020.drop(["Special Events"], axis=0, inplace=True)
pico_viewers_2020= pico_viewers_2020.head(1)
pico_viewers_2020["Year"]=[2020]
pico_viewers_2020= pico_viewers_2020.reset_index()
pico_viewers_2020.set_index("Year", inplace=True)

copiatotal_viewers2021= total2021.copy()
copiatotal_viewers2021['Peak_viewers'] = copiatotal_viewers2021['Peak_viewers'].astype(int)
pico_viewers_2021= copiatotal_viewers2021.groupby("Game").sum()
pico_viewers_2021=pico_viewers_2021.drop(["Month","Rank"], axis=1)
pico_viewers_2021.sort_values(by=["Peak_viewers"], ascending=False, inplace=True)
pico_viewers_2021.drop(["Talk Shows & Podcasts"], axis=0, inplace=True)
pico_viewers_2021= pico_viewers_2021.head(1)
pico_viewers_2021["Year"]=[2021]
pico_viewers_2021= pico_viewers_2021.reset_index()
pico_viewers_2021.set_index("Year", inplace=True)

copiatotal_viewers2022= total2022.copy()
copiatotal_viewers2022['Peak_viewers'] = copiatotal_viewers2022['Peak_viewers'].astype(int)
pico_viewers_2022= copiatotal_viewers2022.groupby("Game").sum()
pico_viewers_2022=pico_viewers_2022.drop(["Month","Rank"], axis=1)
pico_viewers_2022.sort_values(by=["Peak_viewers"], ascending=False, inplace=True)
pico_viewers_2022.drop(["Just Chatting"], axis=0, inplace=True)
pico_viewers_2022= pico_viewers_2022.head(1)
pico_viewers_2022["Year"]=[2022]
pico_viewers_2022= pico_viewers_2022.reset_index()
pico_viewers_2022.set_index("Year", inplace=True)

pico_viewers_2016
pico_viewers_2017
pico_viewers_2018
pico_viewers_2019
pico_viewers_2020
pico_viewers_2021
pico_viewers_2022

# %%
pico_viewers_total= pd.concat([pico_viewers_2016,pico_viewers_2017,pico_viewers_2018,pico_viewers_2019,pico_viewers_2020,pico_viewers_2021,pico_viewers_2022],axis=0)
pico_viewers_total= pico_viewers_total.reset_index()
pico_viewers_total

# %%
pico_viewers_total.to_csv("CSV/pico viewer en 7 años/pico visualizaciones en 7 años.csv", sep=",", index = True)

# %%
#GRAFICA COMPARACION MAX PICO VIEWERS TWITCH VS EVENTOS DEPORTIVOS

pico_max_twitch= pico_viewers_2021.reset_index()
pico_max_twitch.drop(["Year"],axis=1,inplace=True)
pico_max_twitch.set_index("Game",inplace=True)
pico_max_twitch


datos = [{'Game': "Final mundial 2022 (ESPAÑA)" , 'Peak_viewers': 13005000 }]
final_mundial_2022_españa= pd.DataFrame(datos)
final_mundial_2022_españa.set_index("Game",inplace=True)

datos = [{'Game': "Final mundial 2022 (FRANCIA)" , 'Peak_viewers': 29400000 }]
final_mundial_2022_francia= pd.DataFrame(datos)
final_mundial_2022_francia.set_index("Game",inplace=True)

datos = [{'Game': "Final mundial 2010 (ESPAÑA)" , 'Peak_viewers': 13933000 }]
final_mundial_2010_españa= pd.DataFrame(datos)
final_mundial_2010_españa.set_index("Game",inplace=True)

pico_max_twitch=pico_max_twitch.reset_index()
final_mundial_2022_francia=final_mundial_2022_francia.reset_index()
final_mundial_2022_españa=final_mundial_2022_españa.reset_index()
final_mundial_2010_españa=final_mundial_2010_españa.reset_index()

comparativa= pd.concat([pico_max_twitch,final_mundial_2022_francia,final_mundial_2022_españa,final_mundial_2010_españa])
comparativa= comparativa.sort_values(by="Peak_viewers")
comparativa

# %%
pico_max_twitch.to_csv("CSV/pico viewer en 7 años/twitch.csv", sep=",", index = True)
final_mundial_2022_francia.to_csv("CSV/pico viewer en 7 años/mundial 2022 francia.csv", sep=",", index = True)
final_mundial_2022_españa.to_csv("CSV/pico viewer en 7 años/mundial 2022 españa.csv", sep=",", index = True)
final_mundial_2010_españa.to_csv("CSV/pico viewer en 7 años/mundial 2010.csv", sep=",", index = True)
